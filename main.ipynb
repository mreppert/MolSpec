# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999

# %% [markdown]
# # CHM 676: Molecular Spectroscopy

# %%
from IPython.display import display_markdown
from datetime import date
import datetime
import time
import sys, os

# tic = time.time()
out = !{'if [ ! -d git/CHM676 ]; then cd git; git clone https://github.com/mreppert/CHM676.git; else cd git/CHM676; git fetch --all; git reset --hard origin/master; fi'}
# for line in out:
#     print(line)
# toc = time.time()
# print('{:.1f}'.format(toc - tic) + ' seconds to update materials')


srcdir = 'git/CHM676/src/'
sys.path.append(srcdir)
import schedule

schd = schedule.build_schedule_f2020(srcdir)
schd.print_events()

# flist = !{'ls git/CHM676/*'}
# # text = ''
# for line in flist:
#     #text += '[' + line + '](' + line + ')\n'
#     print(line)
# Out:
#  * Dec 14: Freedom!
